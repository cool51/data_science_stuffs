# %%
import pandas as pd
df=pd.read_csv('survey_results_public.csv')
df.shape
# Out:
# (64461, 61)

# %%
#to get more info of a data on columns 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',500)

# %%
#df alone can display all data by help of max_columns
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#all survey columns are in schema_csv so we load it to view all survey questions  detailed info in survey question
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
#df.head(no of rows you want to see)
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
#we can also use tail to view last values
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# ...

# %% [markdown]
# data frame and series are like objects
# data frame are like dictionary in python but with more functionality
# in laymans term dataframes is  rows and colums but series is like rows of single columns, d
# dataframe is like a container for multiple series object
# lets take example by help of python dictonary

# %%
people={"first":["Mukul","kiran","sandip"],
       "last":["Atreya","Gyawali","Ghimire"],
        "email":["mukul@gmail.com","gyawalkiran@gmail.com","ghimire#gmail.com"]
       }
dictonary=pd.DataFrame(people)
dictonary ##it is a data frame which has rows and columns
# Out:
#     first     last                  email
# 0   Mukul   Atreya        mukul@gmail.com
# 1   kiran  Gyawali  gyawalkiran@gmail.com
# 2  sandip  Ghimire      ghimire#gmail.com

# %%
#now to see series
dictonary['email']
#type(dictonary['email'])
# Out:
# 0          mukul@gmail.com
# 1    gyawalkiran@gmail.com
# 2        ghimire#gmail.com
# Name: email, dtype: object

# %%
dictonary.email
# Out:
# 0          mukul@gmail.com
# 1    gyawalkiran@gmail.com
# 2        ghimire#gmail.com
# Name: email, dtype: object

# %%
dictonary[['first','email']]
type(dictonary[['last','email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# To access row we use iloc

# %%
dictonary.iloc[2]
# Out:
# first               sandip
# last               Ghimire
# email    ghimire#gmail.com
# Name: 2, dtype: object

# %%
dictonary.iloc[0:3,2]
# Out:
# 0          mukul@gmail.com
# 1    gyawalkiran@gmail.com
# 2        ghimire#gmail.com
# Name: email, dtype: object

# %% [markdown]
# loc is label based i.e we pass name of column we want to pass
# iolc is index based i.e we just pass index

# %%
dictonary.loc[[0,1],['email','last']]
# Out:
#                    email     last
# 0        mukul@gmail.com   Atreya
# 1  gyawalkiran@gmail.com  Gyawali

# %%
#lets apply it in real data
df.shape
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.iloc[3333:3338,6:10]
# Out:
#       CompTotal  ConvertedComp        Country          CurrencyDesc
# 3333   230000.0       230000.0  United States  United States dollar
# 3334   210187.0       210187.0  United States  United States dollar
# 3335   140000.0       140000.0  United States  United States dollar
# 3336        NaN            NaN  United States  United States dollar
# 3337   120000.0       120000.0  United States  United States dollar

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# To count no of values in a column we have method

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States                                12469
# India                                         8403
# United Kingdom                                3896
# Germany                                       3890
# Canada                                        2191
# France                                        1898
# Brazil                                        1818
# Netherlands                                   1343
# Poland                                        1278
# Australia                                     1208
# Spain                                         1161
# Italy                                         1117
# Russian Federation                            1092
# Sweden                                         886
# Pakistan                                       809
# Turkey                                         777
# Israel                                         653
# Switzerland                                    629
# ...

# %%
# to get slicing in country

df.loc[0:5,'Hobbyist':'Sexuality']
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
# 5       No   NaN         14      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
# 3             Albania    Albanian lek            ALL                    NaN
# 4       United States             NaN            NaN       MySQL;PostgreSQL
# ...

# %%
#we can set our own index

# %%
#search by label
schema_df.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %% [markdown]
# # More Advanced Filtering in Pandas

# %%
((df['Country']=='India')&(df['ConvertedComp']>1000)&(df['Age']>35)).value_counts()

#df.loc[filt]
# Out:
# False    64351
# True       110
# dtype: int64

# %%
((df['Country']=='India')&(df['Age']>35)).value_counts()
# Out:
# False    64241
# True       220
# dtype: int64

# %%
df.loc[filt]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-dd2249f382f6> in <module>
# ----> 1 df.loc[filt]
#       2
#
# NameError: name 'filt' is not defined

# %%
schema_df.loc['YearsCodePro','QuestionText']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
countries=['United States','India','Nepal']
nfilt=df['Country'].isin(countries)

# %%
df.loc[nfilt,'Country']
# Out:
# 4        United States
# 6                India
# 7        United States
# 13       United States
# 16       United States
#              ...
# 64442            India
# 64443    United States
# 64448            Nepal
# 64452            India
# 64456    United States
# Name: Country, Length: 21114, dtype: object

# %%
#Lfilt=((df['LanguageWorkedWith'].str.contains('Bash',na=False)) | (df['Country'=='India']))
Lfilt=((df['Country']=='Nepal')&(df['LanguageWorkedWith'].str.contains('Bash',na=False)))
((df['Country']=='Nepal')&(df['LanguageWorkedWith'].str.contains('Bash',na=False))&(df['CompTotal']>50000)).value_counts()
# Out:
# False    64448
# True        13
# dtype: int64

# %%
df.loc[Lfilt,['LanguageWorkedWith','Country','CompTotal','CompFreq']]
# Out:
#                                       LanguageWorkedWith Country  CompTotal  \
# 1349    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python   Nepal    50000.0
# 1813               Bash/Shell/PowerShell;Java;Kotlin;SQL   Nepal   180000.0
# 5991   Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...   Nepal        NaN
# 6230   Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...   Nepal   800000.0
# 6316   Bash/Shell/PowerShell;C;C++;Dart;HTML/CSS;Java...   Nepal        NaN
# 7449   Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...   Nepal        NaN
# 7850   Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...   Nepal    55000.0
# 7912   Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...   Nepal    60000.0
# 7963   Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...   Nepal        NaN
# 8635        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python   Nepal        NaN
# 9401            Bash/Shell/PowerShell;Go;Java;PHP;Python   Nepal        NaN
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('Assembly',na=False)

# %%
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 67             68             I am a student who is learning to code      Yes
# 73             74                     I am a developer by profession      Yes
# 75             76             I am a student who is learning to code      Yes
# 91             93  I am not primarily a developer, but I write co...      Yes
# 113           115                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64413       58498                                                NaN      Yes
# 64420       59132                                                NaN      Yes
# 64421       59168                                                NaN      Yes
# 64426       60134                                                NaN      Yes
# 64457       64867                                                NaN      Yes
#
# ...

# %% [markdown]
# # Update data i.e change data

# %%
people
# Out:
# {'first': ['Mukul', 'kiran', 'sandip'],
#  'last': ['Atreya', 'Gyawali', 'Ghimire'],
#  'email': ['mukul@gmail.com', 'gyawalkiran@gmail.com', 'ghimire#gmail.com']}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last                  email
# 0   Mukul   Atreya        mukul@gmail.com
# 1   kiran  Gyawali  gyawalkiran@gmail.com
# 2  sandip  Ghimire      ghimire#gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# change column names
df.columns=['First','Last','Email']

# %%
df
# Out:
#     First     Last                  Email
# 0   Mukul   Atreya        mukul@gmail.com
# 1   kiran  Gyawali  gyawalkiran@gmail.com
# 2  sandip  Ghimire      ghimire#gmail.com

# %%
#to replace certain char or string from whole column like replace space by _ 
df.columns=df.columns.str.replace('a','A')
df
# Out:
#     First     LAst                  EmAil
# 0   Mukul   Atreya        mukul@gmail.com
# 1   kiran  Gyawali  gyawalkiran@gmail.com
# 2  sandip  Ghimire      ghimire#gmail.com

# %%
#to change of ceraion columns
#we send dictonary key to fuction

df.rename(columns={'First':'First_Name','LAst':'Last_Name','EmAil':'Email_Address'})
# Out:
#   First_Name Last_Name          Email_Address
# 0      Mukul    Atreya        mukul@gmail.com
# 1      kiran   Gyawali  gyawalkiran@gmail.com
# 2     sandip   Ghimire      ghimire#gmail.com

# %%
df
#inorder to make permanent change put inplace =True
df.rename(columns={'First':'First_Name','LAst':'Last_Name','EmAil':'Email_Address'},inplace=True)
df
# Out:
#   First_Name Last_Name          Email_Address
# 0      Mukul    Atreya        mukul@gmail.com
# 1      kiran   Gyawali  gyawalkiran@gmail.com
# 2     sandip   Ghimire      ghimire#gmail.com
